# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
GCMs_DF = pd.read_csv('NSS_GreatCare_Members.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d1388477a4f> in <module>
# ----> 1 GCms_DF = pd.read_csv('NSS_GreatCare_Members.csv')
#
# NameError: name 'pd' is not defined
